# %%
from src.rest_api.rest_build import RestBuilder


b = RestBuilder("hhtp://api/teste")
b.m_method(b.METHOD_GET)
b.m_to_string()
# Out:
#         ENDPOINT = hhtp://api/teste
#         METHOD   = GET

# %%
# PESQUISAR CONVÊNIOS
import pandas as pd
import json


from src.WSPortalConvenio import WSPortalConvenio
ws_portal_convenio = WSPortalConvenio("convenio/ws/WSPortalConvenio.php")


orgao_concedente_id = 7
tipo_instrumento_id = 1
num_convenio = ""
ano_convenio = 2023

resultado = ws_portal_convenio.m_pesquisar_convenio(
    orgao_concedente_id, 
    tipo_instrumento_id,
    num_convenio,
    ano_convenio )

# print( resultado['query'].iloc[0] )
# print( resultado['num_convenio'].iloc[0] )
resultado

# %%
import pandas as pd
import json

# FALTA TERMINAR
from src.WSPortalConvenio import WSPortalConvenio
ws_portal_convenio = WSPortalConvenio("convenio/ws/WSPortalConvenio.php")


# ws_portal_convenio.m_get_all()

# ws_portal_convenio.m_find_by_id(4)

#ws_portal_convenio.m_insert(cod_org= 15, convenio_ano=2022)
'''
cod_org = 7
convenio_ano = 2023
cod_tipo_instrumento = 1
num_convenio = 56
cod_convenio_format = "TR"+str(cod_org) +"01"+ "."+str(num_convenio)
cod_orgao_convenente = 10
cod_entidade_convenente = None 
objeto =  "Objeto Teste dia 10/11/2023"
dt_inicial_vigencia = "2023-11-01"
data_fim_vigencia = "2023-11-05"
dt_limite_contas = "2023-11-30"
vl_pactuado = 25000.26
vl_contrapartida_pecunia = 156.89

resultado = ws_portal_convenio.m_insert(
            cod_org, 
            convenio_ano,
            cod_tipo_instrumento,
            num_convenio,
            cod_convenio_format,
            cod_orgao_convenente,
            cod_entidade_convenente,
            objeto,
            dt_inicial_vigencia,
            data_fim_vigencia,
            dt_limite_contas,
            vl_pactuado,
            vl_contrapartida_pecunia
            )
'''

## UPLOAD DE UM ARQUIVO
# convenio_id = 28
# tipo_axexo = 2 # instrumento
# anexo = [('_anexo_', ('arquivos_teste/pdf_teste1.pdf', open("arquivos_teste/pdf_teste1.pdf", 'rb'), 'application/pdf' ) )]

# resultado = ws_portal_convenio.m_up_load_arquivo(
#             convenio_id,
#             tipo_axexo,
#             anexo
#         )
# info = json.loads(resultado)
# data = pd.json_normalize(info) 
# data




# ## UPLOAD DE UM ARQUIVO
# convenio_id = 32
# tipo_axexo = 1 # instrumento
# anexo = [('_anexo_instrumento_', ('arquivos_teste/pdf_teste1.pdf', open("arquivos_teste/pdf_teste1.pdf", 'rb'), 'application/pdf' ) )]

# resultado = ws_portal_convenio.m_upload_instrumento(
#             convenio_id,
#             tipo_axexo,
#             anexo
#         )
# info = json.loads(resultado)
# data = pd.json_normalize(info) 
# data




# LISTA TIPOS DE ANEXOS
# resultado = ws_portal_convenio.m_tipo_termos_all()
# resultado

# LISTAR AQUIVOS ANEXADOS VALIDOS
'''
convenio_id = 32
resultado = ws_portal_convenio.m_listar_arquivos_anexados(convenio_id)
resultado
'''

# %%
# PESQUISAR CONVÊNIOS
import pandas as pd
import json


from src.WSPortalConvenio import WSPortalConvenio
ws_portal_convenio = WSPortalConvenio("convenio/ws/WSPortalConvenio.php")


orgao_concedente_id = 7
tipo_instrumento_id = 1
num_convenio = ""
ano_convenio = 2023

resultado = ws_portal_convenio.m_pesquisar_convenio(
    orgao_concedente_id, 
    tipo_instrumento_id,
    num_convenio,
    ano_convenio )

# print( resultado['query'].iloc[0] )
# print( resultado['num_convenio'].iloc[0] )
resultado

# %%
# PESQUISAR CONVÊNIOS
import pandas as pd
import json


from src.WSPortalConvenio import WSPortalConvenio
ws_portal_convenio = WSPortalConvenio("convenio/ws/WSPortalConvenio.php")


orgao_concedente_id = 7
tipo_instrumento_id = 1
num_convenio = ""
ano_convenio = 2023

resultado = ws_portal_convenio.m_pesquisar_convenio(
    orgao_concedente_id, 
    tipo_instrumento_id,
    num_convenio,
    ano_convenio )

# print( resultado['query'].iloc[0] )
# print( resultado['num_convenio'].iloc[0] )
resultado

# %%
from src.WSConvenenteExterno import WSConvenenteExterno

ws_convenente_externo = WSConvenenteExterno("convenio/ws/WSConvenenteExterno.php")

# ws_convenente_externo.m_find_by_id(4031)

#ws_convenente_externo.m_find_by_cpf("0")

ws_convenente_externo.m_find_by_cnpj("5087")

# ws_convenente_externo.m_find_by_name("ana fa")

# %%
from src.WSTipoTermo import WSTipoTermo


ws_tipo_termo = WSTipoTermo("convenio/ws/WSTipoTermo.php")

#ws_tipo_termo.m_find_by_id(1)

# ws_tipo_termo.m_delete(6)

# ws_tipo_termo.m_insert("Termo Outros")

ws_tipo_termo.m_get_all()

# ws_tipo_termo.m_update(6, "Termos Outros alterado")
